# %% [markdown]
# ## Exploratory Machine Learning Analysis
#
# We have a main dataset that we will use to train a model, and predict the Life Ladder values.

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies.
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Main dataset.
df = pd.read_csv('ds19_happ_temp_cw_gg_pop_pm_co2.csv')
df.head()
# Out:
#        Country  Year  Life Ladder  Temperature  Clean Water  \
# 0  Afghanistan  2010        4.758       14.629     48.28708
# 1  Afghanistan  2011        3.832       16.487     50.82785
# 2  Afghanistan  2012        3.783       14.373     53.40352
# 3  Afghanistan  2013        3.572       16.156     56.01404
# 4  Afghanistan  2014        3.131       15.647     58.65937
#
#    Greenhouse Gas Emissions  Population     PM2.5  CO2 Emissions
# 0                   44910.0  29185511.0  52.49585      8397779.0
# 1                   58650.0  30117411.0  57.09972     12105788.0
# 2                   66750.0  31161378.0  55.46611     10218514.0
# 3                   74800.0  32269592.0  59.62277      8440766.0
# 4                   84620.0  33370804.0  62.72192      7774340.0

# %%
# Drop any and all NaN values.
df = df.dropna()
df.head()
# Out:
#        Country  Year  Life Ladder  Temperature  Clean Water  \
# 0  Afghanistan  2010        4.758       14.629     48.28708
# 1  Afghanistan  2011        3.832       16.487     50.82785
# 2  Afghanistan  2012        3.783       14.373     53.40352
# 3  Afghanistan  2013        3.572       16.156     56.01404
# 4  Afghanistan  2014        3.131       15.647     58.65937
#
#    Greenhouse Gas Emissions  Population     PM2.5  CO2 Emissions
# 0                   44910.0  29185511.0  52.49585      8397779.0
# 1                   58650.0  30117411.0  57.09972     12105788.0
# 2                   66750.0  31161378.0  55.46611     10218514.0
# 3                   74800.0  32269592.0  59.62277      8440766.0
# 4                   84620.0  33370804.0  62.72192      7774340.0

# %% [markdown]
# This time we will **DROP** the **Country** and **Year** columns.

# %%
# Drop ID and year columns.
df.drop(columns=['Country', 'Year'], inplace=True)
df.head()
# Out:
#    Life Ladder  Temperature  Clean Water  Greenhouse Gas Emissions  \
# 0        4.758       14.629     48.28708                   44910.0
# 1        3.832       16.487     50.82785                   58650.0
# 2        3.783       14.373     53.40352                   66750.0
# 3        3.572       16.156     56.01404                   74800.0
# 4        3.131       15.647     58.65937                   84620.0
#
#    Population     PM2.5  CO2 Emissions
# 0  29185511.0  52.49585      8397779.0
# 1  30117411.0  57.09972     12105788.0
# 2  31161378.0  55.46611     10218514.0
# 3  32269592.0  59.62277      8440766.0
# 4  33370804.0  62.72192      7774340.0

# %%
# Split values.
X = df.drop(columns='Life Ladder')
y = df['Life Ladder']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
# Create regression model.
model = LinearRegression(n_jobs=-1)

# %%
# Fit the model.
model.fit(X_train, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
# Make predictions.
pred = model.predict(X_test)

# %%
# Compare the results.
results = pd.DataFrame(zip(pred, y_test), columns=['Predicted', 'Actual'])
results['Difference'] = abs(results['Predicted'] - results['Actual'])
results
# Out:
#      Predicted  Actual  Difference
# 0     4.902156   4.461    0.441156
# 1     6.263049   6.263    0.000049
# 2     5.660952   5.590    0.070952
# 3     5.698678   4.773    0.925678
# 4     3.051451   5.164    2.112549
# ..         ...     ...         ...
# 216   4.954513   4.669    0.285513
# 217   6.249571   5.911    0.338571
# 218   4.754599   3.616    1.138599
# 219   4.336557   5.100    0.763443
# 220   3.757958   3.783    0.025042
#
# [221 rows x 3 columns]

# %%
# Style.
from matplotlib import style
style.use('fivethirtyeight')

# %%
# Try and plot the differences.
bins = [0, 40, 80, 120, 160]
for i in bins:
    results.iloc[i:i+40].plot(y=['Predicted', 'Actual'], figsize=(15,3.5))

# %%
# Save results DF to compare to 20_ml.
results.to_csv('ml_results/21_ml_results.csv', index=False)
