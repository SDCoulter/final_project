# %% [markdown]
# ## Create the Population Database Table

# %%
# Dependencies.
import pandas as pd

# %%
# Greenhouse gas cleaned data.
pop_df = pd.read_csv('../resources/populations.csv')
pop_df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2011         2012         2013         2014  \
# ...

# %%
# Gather only needed columns.
pop_df = pop_df[['Country Name', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']]
pop_df.rename(columns={
    'Country Name': 'Country',
    '2010': 2010,
    '2011': 2011,
    '2012': 2012,
    '2013': 2013,
    '2014': 2014,
    '2015': 2015,
    '2016': 2016,
    '2017': 2017,
    '2018': 2018,
    '2019': 2019
}, inplace=True)
pop_df.head()
# Out:
#                        Country         2010         2011         2012  \
# 0                        Aruba     101665.0     102050.0     102565.0
# 1  Africa Eastern and Southern  518468229.0  532760424.0  547482863.0
# 2                  Afghanistan   29185511.0   30117411.0   31161378.0
# 3   Africa Western and Central  350556886.0  360285439.0  370243017.0
# 4                       Angola   23356247.0   24220660.0   25107925.0
#
#           2013         2014         2015         2016         2017  \
# 0     103165.0     103776.0     104339.0     104865.0     105361.0
# 1  562601578.0  578075373.0  593871847.0  609978946.0  626392880.0
# 2   32269592.0   33370804.0   34413603.0   35383028.0   36296111.0
# 3  380437896.0  390882979.0  401586651.0  412551299.0  423769930.0
# 4   26015786.0   26941773.0   27884380.0   28842482.0   29816769.0
#
#           2018         2019
# 0     105846.0     106310.0
# 1  643090131.0  660046272.0
# 2   37171922.0   38041757.0
# ...

# %%
# Fix country names.
pop_df.set_index('Country', inplace=True)
pop_df.rename(index={
    'Egypt, Arab Rep.': 'Egypt',
    'Kyrgyz Republic': 'Kyrgyzstan',
    'North Macedonia': 'Macedonia',
    'Russian Federation': 'Russia',
    'Slovak Republic': 'Slovakia',
    'Korea, Rep.': 'South Korea',
    'Venezuela, RB': 'Venezuela',
    'Yemen, Rep.': 'Yemen'
}, inplace=True)
pop_df.head()
# Out:
#                                     2010         2011         2012  \
# Country
# Aruba                           101665.0     102050.0     102565.0
# Africa Eastern and Southern  518468229.0  532760424.0  547482863.0
# Afghanistan                   29185511.0   30117411.0   31161378.0
# Africa Western and Central   350556886.0  360285439.0  370243017.0
# Angola                        23356247.0   24220660.0   25107925.0
#
#                                     2013         2014         2015  \
# Country
# Aruba                           103165.0     103776.0     104339.0
# Africa Eastern and Southern  562601578.0  578075373.0  593871847.0
# Afghanistan                   32269592.0   33370804.0   34413603.0
# Africa Western and Central   380437896.0  390882979.0  401586651.0
# Angola                        26015786.0   26941773.0   27884380.0
#
#                                     2016         2017         2018  \
# Country
# ...

# %%
# Keep only those 100 countries we need.
countries = pd.read_csv('MAIN_table.csv', index_col='Country').index.unique().tolist()
pop_df_1 = pop_df.loc[pop_df.index.isin(countries)]
pop_df_1.head()
# Out:
#                             2010        2011        2012        2013  \
# Country
# Afghanistan           29185511.0  30117411.0  31161378.0  32269592.0
# Albania                2913021.0   2905195.0   2900401.0   2895092.0
# United Arab Emirates   8549998.0   8946778.0   9141598.0   9197908.0
# Argentina             40788453.0  41261490.0  41733271.0  42202935.0
# Armenia                2877314.0   2876536.0   2884239.0   2897593.0
#
#                             2014        2015        2016        2017  \
# Country
# Afghanistan           33370804.0  34413603.0  35383028.0  36296111.0
# Albania                2889104.0   2880703.0   2876101.0   2873457.0
# United Arab Emirates   9214182.0   9262896.0   9360975.0   9487206.0
# Argentina             42669500.0  43131966.0  43590368.0  44044811.0
# Armenia                2912403.0   2925559.0   2936147.0   2944789.0
#
#                             2018        2019
# Country
# Afghanistan           37171922.0  38041757.0
# ...

# %%
# Sort index alphabetically.
pop_df_1 = pop_df_1.sort_index(axis=0)
pop_df_1.head()
# Out:
#                    2010        2011        2012        2013        2014  \
# Country
# Afghanistan  29185511.0  30117411.0  31161378.0  32269592.0  33370804.0
# Albania       2913021.0   2905195.0   2900401.0   2895092.0   2889104.0
# Argentina    40788453.0  41261490.0  41733271.0  42202935.0  42669500.0
# Armenia       2877314.0   2876536.0   2884239.0   2897593.0   2912403.0
# Australia    22031750.0  22340024.0  22733465.0  23128129.0  23475686.0
#
#                    2015        2016        2017        2018        2019
# Country
# Afghanistan  34413603.0  35383028.0  36296111.0  37171922.0  38041757.0
# Albania       2880703.0   2876101.0   2873457.0   2866376.0   2854191.0
# Argentina    43131966.0  43590368.0  44044811.0  44494502.0  44938712.0
# Armenia       2925559.0   2936147.0   2944789.0   2951741.0   2957728.0
# Australia    23815995.0  24190907.0  24601860.0  24982688.0  25365745.0

# %%
# Save DataFrame.
pop_df_1.to_csv('country_index/population_table.csv')
pop_df_1.head()
# Out:
#                    2010        2011        2012        2013        2014  \
# Country
# Afghanistan  29185511.0  30117411.0  31161378.0  32269592.0  33370804.0
# Albania       2913021.0   2905195.0   2900401.0   2895092.0   2889104.0
# Argentina    40788453.0  41261490.0  41733271.0  42202935.0  42669500.0
# Armenia       2877314.0   2876536.0   2884239.0   2897593.0   2912403.0
# Australia    22031750.0  22340024.0  22733465.0  23128129.0  23475686.0
#
#                    2015        2016        2017        2018        2019
# Country
# Afghanistan  34413603.0  35383028.0  36296111.0  37171922.0  38041757.0
# Albania       2880703.0   2876101.0   2873457.0   2866376.0   2854191.0
# Argentina    43131966.0  43590368.0  44044811.0  44494502.0  44938712.0
# Armenia       2925559.0   2936147.0   2944789.0   2951741.0   2957728.0
# Australia    23815995.0  24190907.0  24601860.0  24982688.0  25365745.0

# %%
# Stack and save the database table.
stack_df = pd.DataFrame(pop_df_1.stack())
stack_df.index.set_names(['Country', 'Year'], inplace=True)
stack_df.rename(columns={0: 'Population'}, inplace=True)
stack_df.to_csv('population_table.csv')
stack_df.head()
# Out:
#                   Population
# Country     Year
# Afghanistan 2010  29185511.0
#             2011  30117411.0
#             2012  31161378.0
#             2013  32269592.0
#             2014  33370804.0
