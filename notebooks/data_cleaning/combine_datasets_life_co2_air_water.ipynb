# %%
import pandas as pd

# %%
df1 = pd.read_csv('resources/co2_happiness_modified.csv')
df2 = pd.read_csv('resources/air_water.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0      Country Code  Year  Annual_CO2_emission_tonnes  \
# 0           0  Afghanistan  AFG  2008                  4198329.64
# 1           1  Afghanistan  AFG  2009                  6760313.49
# 2           2  Afghanistan  AFG  2010                  8452224.14
# 3           3  Afghanistan  AFG  2011                 12226017.38
# 4           4  Afghanistan  AFG  2012                 10742056.72
#
#    Life_ladder  Log_GDP_per_capita  Social_support  Life_expectancy_at_birth  \
# 0        3.724               7.370           0.451                     50.80
# 1        4.402               7.540           0.552                     51.20
# 2        4.758               7.647           0.539                     51.60
# 3        3.832               7.620           0.521                     51.92
# 4        3.783               7.705           0.521                     52.24
#
#    Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption  \
# ...

# %%
df2.head()
# Out:
#    Unnamed: 0      Country Code  Year  Basic_drinking_water  \
# 0           0  Afghanistan  AFG  2008                 43.31
# 1           1  Afghanistan  AFG  2009                 45.78
# 2           2  Afghanistan  AFG  2010                 48.29
# 3           3  Afghanistan  AFG  2011                 50.83
# 4           4  Afghanistan  AFG  2012                 53.40
#
#    Air_pollutant_pm2.5
# 0                  NaN
# 1                  NaN
# 2                49.80
# 3                50.30
# 4                54.67

# %%
df1.drop(columns='Unnamed: 0', inplace=True)
df2.drop(columns='Unnamed: 0', inplace=True)

# %%
df1.head()
# Out:
#        Country Code  Year  Annual_CO2_emission_tonnes  Life_ladder  \
# 0  Afghanistan  AFG  2008                  4198329.64        3.724
# 1  Afghanistan  AFG  2009                  6760313.49        4.402
# 2  Afghanistan  AFG  2010                  8452224.14        4.758
# 3  Afghanistan  AFG  2011                 12226017.38        3.832
# 4  Afghanistan  AFG  2012                 10742056.72        3.783
#
#    Log_GDP_per_capita  Social_support  Life_expectancy_at_birth  \
# 0               7.370           0.451                     50.80
# 1               7.540           0.552                     51.20
# 2               7.647           0.539                     51.60
# 3               7.620           0.521                     51.92
# 4               7.705           0.521                     52.24
#
#    Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption  \
# 0                         0.718       0.168                      0.882
# ...

# %%
df2.head()
# Out:
#        Country Code  Year  Basic_drinking_water  Air_pollutant_pm2.5
# 0  Afghanistan  AFG  2008                 43.31                  NaN
# 1  Afghanistan  AFG  2009                 45.78                  NaN
# 2  Afghanistan  AFG  2010                 48.29                49.80
# 3  Afghanistan  AFG  2011                 50.83                50.30
# 4  Afghanistan  AFG  2012                 53.40                54.67

# %%
new_df = df1.merge(df2, how='left')

# %%
new_df.head(15)
# Out:
#         Country Code  Year  Annual_CO2_emission_tonnes  Life_ladder  \
# 0   Afghanistan  AFG  2008                  4198329.64        3.724
# 1   Afghanistan  AFG  2009                  6760313.49        4.402
# 2   Afghanistan  AFG  2010                  8452224.14        4.758
# 3   Afghanistan  AFG  2011                 12226017.38        3.832
# 4   Afghanistan  AFG  2012                 10742056.72        3.783
# 5   Afghanistan  AFG  2013                 10000414.29        3.572
# 6   Afghanistan  AFG  2014                  9789185.57        3.131
# 7   Afghanistan  AFG  2015                 10107428.68        3.983
# 8   Afghanistan  AFG  2016                 12257907.69        4.220
# 9   Afghanistan  AFG  2017                 13014739.66        2.662
# 10      Albania  ALB  2009                  4374816.00        5.485
# 11      Albania  ALB  2010                  4594656.00        5.269
# 12      Albania  ALB  2011                  5235856.00        5.867
# ...

# %%
new_df.drop(['Log_GDP_per_capita','Social_support','Life_expectancy_at_birth','Freedom_to_make_life_choices','Generosity','Perceptions_of_corruption','Positive_affect', 'Negative_affect'], axis=True, inplace=True)

# %%
new_df.head()
# Out:
#        Country Code  Year  Annual_CO2_emission_tonnes  Life_ladder  \
# 0  Afghanistan  AFG  2008                  4198329.64        3.724
# 1  Afghanistan  AFG  2009                  6760313.49        4.402
# 2  Afghanistan  AFG  2010                  8452224.14        4.758
# 3  Afghanistan  AFG  2011                 12226017.38        3.832
# 4  Afghanistan  AFG  2012                 10742056.72        3.783
#
#    Basic_drinking_water  Air_pollutant_pm2.5
# 0                 43.31                  NaN
# 1                 45.78                  NaN
# 2                 48.29                49.80
# 3                 50.83                50.30
# 4                 53.40                54.67

# %%
new_df.to_csv('resources/environment_happiness.csv')
