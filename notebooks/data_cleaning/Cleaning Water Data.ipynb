# %%
import pandas as pd

# %%
data = pd.read_csv('WSH_WATER_SAFELY_MANAGED,WSH_WATER_BASIC.csv')
data
# Out:
#       COUNTRY (DISPLAY)  YEAR (CODE)  YEAR (DISPLAY)  YEAR (URL)  \
# 0           Afghanistan         2000            2000         NaN
# 1           Afghanistan         2000            2000         NaN
# 2           Afghanistan         2000            2000         NaN
# 3           Afghanistan         2001            2001         NaN
# 4           Afghanistan         2001            2001         NaN
# ...                 ...          ...             ...         ...
# 24691          Zimbabwe         2019            2019         NaN
# 24692          Zimbabwe         2019            2019         NaN
# 24693          Zimbabwe         2020            2020         NaN
# 24694          Zimbabwe         2020            2020         NaN
# 24695          Zimbabwe         2020            2020         NaN
#
#       REGION (CODE)       REGION (DISPLAY) COUNTRY (CODE)  \
# 0               EMR  Eastern Mediterranean            AFG
# 1               EMR  Eastern Mediterranean            AFG
# ...

# %%
new_data = data.drop(["YEAR (CODE)", "YEAR (URL)", "REGION (CODE)", "RESIDENCEAREATYPE (CODE)", "RESIDENCEAREATYPE (DISPLAY)"], axis=True, inplace=True)
new_data.head()

# %%
data
# Out:
#       COUNTRY (DISPLAY)  YEAR (DISPLAY)       REGION (DISPLAY) COUNTRY (CODE)  \
# 0           Afghanistan            2000  Eastern Mediterranean            AFG
# 1           Afghanistan            2000  Eastern Mediterranean            AFG
# 2           Afghanistan            2000  Eastern Mediterranean            AFG
# 3           Afghanistan            2001  Eastern Mediterranean            AFG
# 4           Afghanistan            2001  Eastern Mediterranean            AFG
# ...                 ...             ...                    ...            ...
# 24691          Zimbabwe            2019                 Africa            ZWE
# 24692          Zimbabwe            2019                 Africa            ZWE
# 24693          Zimbabwe            2020                 Africa            ZWE
# 24694          Zimbabwe            2020                 Africa            ZWE
# 24695          Zimbabwe            2020                 Africa            ZWE
#
#        Display Value   Numeric
# ...

# %%
data.to_csv('Cleaned_Water_Data.csv')
