# %% [markdown]
# ### Citation: University of Dayton - Environmental Protection Agency Average Daily Temperature Archive,
# http://academic.udayton.edu/kissock/http/Weather/default.htm
#
# ### Terms of Use: Source data for this site are from the National Climatic Data Center. The data is available for research and non-commercial purposes only.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../city_temperature.csv', low_memory=False)

# %%
df.drop(['State', 'Region'], axis=1, inplace=True)

# %%
df.sort_values(by='Country', ascending=True)
df.head()
# Out:
#    Country     City  Month  Day  Year  AvgTemperature
# 0  Algeria  Algiers      1    1  1995            64.2
# 1  Algeria  Algiers      1    2  1995            49.4
# 2  Algeria  Algiers      1    3  1995            48.8
# 3  Algeria  Algiers      1    4  1995            46.4
# 4  Algeria  Algiers      1    5  1995            47.9

# %%
df[df['Country'] == 'Albania']
# Out:
#         Country    City  Month  Day  Year  AvgTemperature
# 623377  Albania  Tirana      1    1  1995           -99.0
# 623378  Albania  Tirana      1    2  1995           -99.0
# 623379  Albania  Tirana      1    3  1995           -99.0
# 623380  Albania  Tirana      1    4  1995           -99.0
# 623381  Albania  Tirana      1    5  1995           -99.0
# ...         ...     ...    ...  ...   ...             ...
# 632638  Albania  Tirana      5    9  2020            62.4
# 632639  Albania  Tirana      5   10  2020            60.5
# 632640  Albania  Tirana      5   11  2020            65.2
# 632641  Albania  Tirana      5   12  2020            68.5
# 632642  Albania  Tirana      5   13  2020            54.4
#
# [9266 rows x 6 columns]

# %%
table = pd.pivot_table(df, values='AvgTemperature', index=['Country', 'Year'], aggfunc=np.mean)

# %%
table.head()
# Out:
#               AvgTemperature
# Country Year
# Albania 1995      -99.000000
#         1996      -99.000000
#         1997      -88.228767
#         1998      -46.195890
#         1999       26.696164

# %%
table.reset_index(inplace=True)

# %%
new_df = table

# %%
new_df.head()
# Out:
#    Country  Year  AvgTemperature
# 0  Albania  1995      -99.000000
# 1  Albania  1996      -99.000000
# 2  Albania  1997      -88.228767
# 3  Albania  1998      -46.195890
# 4  Albania  1999       26.696164

# %%
new_df = new_df[new_df['Year'] >= 2008]

# %%
new_df.head()
# Out:
#     Country  Year  AvgTemperature
# 13  Albania  2008       59.790710
# 14  Albania  2009       59.401096
# 15  Albania  2010       60.568767
# 16  Albania  2011       59.918630
# 17  Albania  2012       59.884426

# %%
len(new_df['Country'].unique())
# Out:
# 121

# %%
len(df['Country'].unique())
# Out:
# 125

# %%
# Check missing countries
for country in df['Country'].unique():
    if country not in new_df['Country'].unique():
        print(country)
        
# These countries do not have data beyond 2007
# Out:
# Burundi
# Georgia
# Serbia-Montenegro
# Israel

# %%
new_df.reset_index(drop=True, inplace=True)
new_df.head(10)
# Out:
#    Country  Year  AvgTemperature
# 0  Albania  2008       59.790710
# 1  Albania  2009       59.401096
# 2  Albania  2010       60.568767
# 3  Albania  2011       59.918630
# 4  Albania  2012       59.884426
# 5  Albania  2013       60.413151
# 6  Albania  2014       60.215616
# 7  Albania  2015       60.090164
# 8  Albania  2016       58.986885
# 9  Albania  2017       60.384658

# %%
base_df = pd.read_csv('resources/environment_happiness.csv', index_col=0)
base_df.head(10)
# Out:
#        Country Code  Year  Annual_CO2_emission_tonnes  Life_ladder  \
# 0  Afghanistan  AFG  2008                  4198329.64        3.724
# 1  Afghanistan  AFG  2009                  6760313.49        4.402
# 2  Afghanistan  AFG  2010                  8452224.14        4.758
# 3  Afghanistan  AFG  2011                 12226017.38        3.832
# 4  Afghanistan  AFG  2012                 10742056.72        3.783
# 5  Afghanistan  AFG  2013                 10000414.29        3.572
# 6  Afghanistan  AFG  2014                  9789185.57        3.131
# 7  Afghanistan  AFG  2015                 10107428.68        3.983
# 8  Afghanistan  AFG  2016                 12257907.69        4.220
# 9  Afghanistan  AFG  2017                 13014739.66        2.662
#
#    Basic_drinking_water  Air_pollutant_pm2.5
# 0                 43.31                  NaN
# 1                 45.78                  NaN
# 2                 48.29                49.80
# 3                 50.83                50.30
# 4                 53.40                54.67
# 5                 56.01                54.89
# 6                 58.66                59.05
# 7                 61.34                54.89
# 8                 64.05                55.14
# 9                 66.81                  NaN

# %%
all_df = base_df.merge(new_df, how='left', on=['Country', 'Year'])
all_df.head(10)
# Out:
#        Country Code  Year  Annual_CO2_emission_tonnes  Life_ladder  \
# 0  Afghanistan  AFG  2008                  4198329.64        3.724
# 1  Afghanistan  AFG  2009                  6760313.49        4.402
# 2  Afghanistan  AFG  2010                  8452224.14        4.758
# 3  Afghanistan  AFG  2011                 12226017.38        3.832
# 4  Afghanistan  AFG  2012                 10742056.72        3.783
# 5  Afghanistan  AFG  2013                 10000414.29        3.572
# 6  Afghanistan  AFG  2014                  9789185.57        3.131
# 7  Afghanistan  AFG  2015                 10107428.68        3.983
# 8  Afghanistan  AFG  2016                 12257907.69        4.220
# 9  Afghanistan  AFG  2017                 13014739.66        2.662
#
#    Basic_drinking_water  Air_pollutant_pm2.5  AvgTemperature
# 0                 43.31                  NaN             NaN
# 1                 45.78                  NaN             NaN
# 2                 48.29                49.80             NaN
# 3                 50.83                50.30             NaN
# 4                 53.40                54.67             NaN
# 5                 56.01                54.89             NaN
# 6                 58.66                59.05             NaN
# 7                 61.34                54.89             NaN
# 8                 64.05                55.14             NaN
# 9                 66.81                  NaN             NaN

# %%
all_df['AvgTempCelcius'] = (all_df['AvgTemperature']-32)*(5/9)

# %%
missing_temp = all_df[all_df['AvgTempCelcius'].isnull() == True]
print(missing_temp['Country'].unique())
# Out:
# ['Afghanistan' 'Angola' 'Armenia' 'Azerbaijan' 'Bangladesh' 'Bhutan'
#  'Bosnia and Herzegovina' 'Botswana' 'Burkina Faso' 'Burundi' 'Cambodia'
#  'Cameroon' 'Chad' 'Chile' 'Comoros' 'Cyprus' 'Djibouti' 'Ecuador'
#  'El Salvador' 'Estonia' 'Georgia' 'Ghana' 'Greece' 'Iran' 'Iraq' 'Israel'
#  'Jamaica' 'Kenya' 'Lesotho' 'Liberia' 'Libya' 'Lithuania' 'Luxembourg'
#  'Malawi' 'Mali' 'Malta' 'Mauritius' 'Moldova' 'Montenegro' 'Myanmar'
#  'Netherlands' 'Niger' 'Paraguay' 'Peru' 'Rwanda' 'Serbia' 'Sierra Leone'
#  'Slovenia' 'Sudan' 'Swaziland' 'Thailand' 'Trinidad and Tobago'
#  'United States' 'Yemen' 'Zambia' 'Zimbabwe']

# %%
all_df[all_df['Country'] == 'Tanzania']
# Out:
#        Country Code  Year  Annual_CO2_emission_tonnes  Life_ladder  \
# 1020  Tanzania  TZA  2008                  5937408.29        4.385
# 1021  Tanzania  TZA  2009                  5693926.63        3.408
# 1022  Tanzania  TZA  2010                  6840606.60        3.229
# 1023  Tanzania  TZA  2011                  7807018.47        4.074
# 1024  Tanzania  TZA  2012                  9238081.98        4.007
# 1025  Tanzania  TZA  2013                 10912008.98        3.852
# 1026  Tanzania  TZA  2014                 11241286.62        3.483
# 1027  Tanzania  TZA  2015                 12453503.48        3.661
# 1028  Tanzania  TZA  2016                 13604691.94        2.903
# 1029  Tanzania  TZA  2017                 14230527.46        3.347
#
#       Basic_drinking_water  Air_pollutant_pm2.5  AvgTemperature  \
# 1020                   NaN                  NaN       70.028142
# 1021                   NaN                  NaN       76.101644
# 1022                   NaN                  NaN       43.101370
# 1023                   NaN                  NaN       76.930959
# 1024                   NaN                  NaN       78.350000
# 1025                   NaN                  NaN       78.637808
# 1026                   NaN                  NaN       76.685792
# 1027                   NaN                  NaN       77.398087
# 1028                   NaN                  NaN       77.290437
# 1029                   NaN                  NaN       79.815342
#
#       AvgTempCelcius
# 1020       21.126746
# 1021       24.500913
# 1022        6.167428
# 1023       24.961644
# 1024       25.750000
# 1025       25.909893
# 1026       24.825440
# 1027       25.221160
# 1028       25.161354
# 1029       26.564079

# %%
all_df[all_df['AvgTempCelcius'].isnull() == False].head(10)
# Out:
#     Country Code  Year  Annual_CO2_emission_tonnes  Life_ladder  \
# 10  Albania  ALB  2009                4.374816e+06        5.485
# 11  Albania  ALB  2010                4.594656e+06        5.269
# 12  Albania  ALB  2011                5.235856e+06        5.867
# 13  Albania  ALB  2012                4.906096e+06        5.510
# 14  Albania  ALB  2013                5.059984e+06        4.551
# 15  Albania  ALB  2014                5.712176e+06        4.814
# 16  Albania  ALB  2015                5.947724e+06        4.607
# 17  Albania  ALB  2016                6.272858e+06        4.511
# 18  Albania  ALB  2017                6.379207e+06        4.640
# 19  Algeria  DZA  2011                1.198069e+08        5.317
#
#     Basic_drinking_water  Air_pollutant_pm2.5  AvgTemperature  AvgTempCelcius
# 10                 90.93                  NaN       59.401096       15.222831
# 11                 91.38                20.09       60.568767       15.871537
# 12                 91.81                22.77       59.918630       15.510350
# 13                 92.23                20.82       59.884426       15.491348
# 14                 92.63                19.91       60.413151       15.785084
# 15                 93.02                19.80       60.215616       15.675342
# 16                 93.39                19.06       60.090164       15.605647
# 17                 93.75                18.07       58.986885       14.992714
# 18                 94.10                  NaN       60.384658       15.769254
# 19                 92.51                29.67       64.960822       18.311568

# %%
all_df.to_csv('resources/env_hap_temp.csv', index=False)
